# %%
import pandas as pd

# %%
df_train = pd.read_csv("C:\\Users\\hs081\\Downloads\\train1.csv\\train.csv")

# %%
df_train.shape
# Out:
# (550068, 12)

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train.shape
# Out:
# (550068, 12)

# %% [markdown]
# # Problem Statement in Kaggle
#
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month.
# The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.
#
# Data

# %%
df_test = pd.read_csv("C:\\Users\\hs081\\Downloads\\test1.csv\\test.csv")

# %%
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df_final = pd.concat([df_train , df_test])

# %%
df_final
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
#basic info

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df_final.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df_final.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df_final.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df_final.drop(['User_ID'] , axis = 1 , inplace = True)

# %%
df_final.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#Data Preprocessing

# %%
#subse phele jo bhee categoircal features honge unko mujhe Encode karke Numercial features me convert kanra hoga
#so that ki hum model ko train kar paye

# %%
#Gende

# %%
df_final.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
# def transform_Num(x):
#     if x == 'F':
#         return 1
#     else:
#         return 0

# %%
# df_final['Gender'] = df_final['Gender'].apply(transform_Num)

# %%
df_final
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df_final['Gender'] = df_final['Gender'].map({'F'  : 1 , 'M' : 0})

# %%
df_final
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       1   0-17          10             A
# 1       P00248942       1   0-17          10             A
# 2       P00087842       1   0-17          10             A
# 3       P00085442       1   0-17          10             A
# 4       P00285442       0    55+          16             C
# ...           ...     ...    ...         ...           ...
# 233594  P00118942       1  26-35          15             B
# 233595  P00254642       1  26-35          15             B
# 233596  P00031842       1  26-35          15             B
# 233597  P00124742       1  46-50           1             C
# 233598  P00316642       1  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df_final.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df_final['Age'] = df_final['Age'].map({'0-17'  : 1 , '18-25' : 2 ,'26-35' : 3 ,  '36-45' : 4  ,'46-50' : 5 ,'51-55' : 6 ,'55+' : 7   })

# %%
df_final
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       1    1          10             A
# 1       P00248942       1    1          10             A
# 2       P00087842       1    1          10             A
# 3       P00085442       1    1          10             A
# 4       P00285442       0    7          16             C
# ...           ...     ...  ...         ...           ...
# 233594  P00118942       1    3          15             B
# 233595  P00254642       1    3          15             B
# 233596  P00031842       1    3          15             B
# 233597  P00124742       1    5           1             C
# 233598  P00316642       1    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df_final.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
df_final['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
d2 = pd.get_dummies(df_final['City_Category'] , drop_first = True)

# %%
df = pd.concat([df_final,d2 ] , axis = 1)

# %%
#city column ki koi zarurat nhi hai

# %%
df.drop('City_Category' ,axis = 1 , inplace = True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       1    3          15                         4+
# 233595  P00254642       1    3          15                         4+
# 233596  P00031842       1    3          15                         4+
# 233597  P00124742       1    5           1                         4+
# 233598  P00316642       1    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
#now lets check for the missing Values

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               uint8
# C                               uint8
# dtype: object

# %%
df['Product_Category_2'].value_counts().plot(kind  = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Product_Category_2'].value_counts().plot(kind  = 'box')
# Out:
# <AxesSubplot:>

# %%
#we will use mode imputation

# %%
mode = list(df['Product_Category_2'].mode())[0]

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(mode)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       1    1          10                          2
# 1  P00248942       1    1          10                          2
# 2  P00087842       1    1          10                          2
# 3  P00085442       1    1          10                          2
# 4  P00285442       0    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 8.0                 NaN
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# 3    1057.0  0  0
# ...

# %%
#same for Product_category - 3

# %%
mode = df['Product_Category_3'].mode()[0]

# %%
mode
# Out:
# 16.0

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(mode)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       1    3          15                         4+
# 233595  P00254642       1    3          15                         4+
# 233596  P00031842       1    3          15                         4+
# 233597  P00124742       1    5           1                         4+
# 233598  P00316642       1    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df['Stay_In_Current_City_Years'].unique() #4+ isko hum 4 hi consider karenge
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
# df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].map({'0' : 0 ,'1' : 1 , '2' : 2 , '3' : 3 , '4+' : 4})

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       1    3          15                         4+
# 233595  P00254642       1    3          15                         4+
# 233596  P00031842       1    3          15                         4+
# 233597  P00124742       1    5           1                         4+
# 233598  P00316642       1    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+' , ' ')
# Out:
# C:\Users\hs081\AppData\Local\Temp\ipykernel_15320\1157122295.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+' , ' ')

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       1    3          15                         4
# 233595  P00254642       1    3          15                         4
# 233596  P00031842       1    3          15                         4
# 233597  P00124742       1    5           1                         4
# 233598  P00316642       1    5           0                         4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 8.0
# ...

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               uint8
# C                               uint8
# dtype: object

# %%
# df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(int)

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               uint8
# C                               uint8
# dtype: object

# %%
df['B'] = df['B'].astype(int)

# %%
df['C'] = df['C'].astype(int)

# %%
df.dtypes
# Out:
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               int32
# C                               int32
# dtype: object

# %%
#now we will do visualization and write the obervation

# %%
import seaborn as sns

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 233594  P00118942       1    3          15                         4+
# 233595  P00254642       1    3          15                         4+
# 233596  P00031842       1    3          15                         4+
# 233597  P00124742       1    5           1                         4+
# 233598  P00316642       1    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
#visualization of age vs purchase

# %%
sns.barplot('Age' , 'Purchase' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %%
#observation -> all age  groups Prachasing are almost same

# %%
sns.barplot('Gender' , 'Purchase' , data = df)
#gender vs purchase
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Purchase'>

# %%
#observation -> males deminates female in purchasing a product (this is very funny fact)
#may be possible feamles uses males credit card for purchasing

# %%
#age(gender) vs purchase

# %%
sns.barplot('Age' , 'Purchase' , data = df , hue = 'Gender')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %%
#observation
#in All Age groups Male Demonates Female in purchasing a product

# %%
df.corr()
# Out:
#                       Gender       Age  Occupation  Marital_Status  \
# Gender              1.000000  0.004758   -0.116505        0.010945
# Age                 0.004758  1.000000    0.090882        0.310747
# Occupation         -0.116505  0.090882    1.000000        0.023563
# Marital_Status      0.010945  0.310747    0.023563        1.000000
# Product_Category_1  0.046208  0.060336   -0.008441        0.019579
# Product_Category_2  0.011851  0.041716    0.001501        0.012192
# Product_Category_3  0.006651  0.036721   -0.001576        0.013808
# Purchase           -0.060346  0.015839    0.020833       -0.000463
# B                   0.005399 -0.016881   -0.011721       -0.002804
# C                   0.000180  0.110302    0.035255        0.034377
#
#                     Product_Category_1  Product_Category_2  \
# Gender                        0.046208            0.011851
# Age                           0.060336            0.041716
# ...

# %%
sns.barplot('Occupation' , 'Purchase' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='Purchase'>

# %%
#observation
#kind of uniform

# %%
#visualization of Marital Status vs purchase
sns.barplot(x = 'Marital_Status' , y = 'Purchase' , data = df , hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='Purchase'>

# %%
#observation 
#it is also uniform ( but men dominates Women)

# %%
sns.barplot('Product_Category_1' , 'Purchase' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Purchase'>

# %%
#observation 
#product having product ID = 10 is the best seller
#product having product ID = 20 is the least seller

# %%
sns.barplot('Product_Category_2' , 'Purchase' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Purchase'>

# %%
#observation
#product having product ID = 10 is the best seller

# %%
sns.barplot('Product_Category_3' , 'Purchase' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Purchase'>

# %%
#observation
#almost uniform

# %%
#Feature Scaling

# %%
df_test.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
df_train = df[~df['Purchase'].isnull()]
X =  df_train.drop('Purchase' , axis = 1)

# %%
X.shape
# Out:
# (550068, 11)

# %%
df_test = df[df['Purchase'].isnull()]
y = df_train['Purchase']

# %%
y.shape
# Out:
# (550068,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
#remove Product Id
X_test.drop('Product_ID' , axis = 1 , inplace = True)

# %%
X_train.drop('Product_ID' , axis = 1 , inplace = True)

# %%
x_train  = scalar.fit_transform(X_train)
x_test = scalar.transform(X_test)

# %%
x_train.shape
# Out:
# (368545, 10)

# %%
y_train.shape
# Out:
# (368545,)

# %%
#model Traning
