# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hs081\\Downloads\\winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.to_csv('Explore_WineDataSet')

# %%
#to check the summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#to check the discriptive Summary of the dataset we use discribe()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#to check the shape of the dataset (no of rows and no of columns)

# %%
df.shape
# Out:
# (1599, 12)

# %%
#to check the name of columns

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#lest check the output feature how many unique will it contain

# %%
df['quality'].unique()
#we have 6 unique values we can check our dataset is balance or imbalance by calculating each value count of the unqiue value
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
#so we can clearly see that our dataset is imbalance
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#now next step to check kahi mere dataset me null values toh present nhi hai by using isnull()
#agr hai toh me feature engineering tech ka use karke unko handle karunga

# %%
df.isnull().sum()
#koi bhee null values nhi hai toh phir yaha mujhe handling nulls nhi karna padega
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#but may be possible ki null values nhi hai toh Duplicate Values ho

# %%
df[df.duplicated()]
#to fetch kitni duplicate values hai
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
#we have 240 Duplicate Values inka mere dataset me koi kaam nhi reheta hai bulki ye jitni zada hongi meri ML algo 
#ki performance utni degrade hogi so , as a result we have to remove this

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape #no duplicate value present
# Out:
# (1359, 12)

# %%
#we can find the relationship between differernt featuers

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
#to check correlation more clearly we use visualztion technique

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot = True)
#heat map se hun asani se correlation pata kar payenge harek feature ko dhek ke and annot is used to display values
# Out:
# <AxesSubplot:>

# %%
#iska size bahut bekar aya , to change size we use figure()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot = True)
#this is correct
#jitna zada light color hai unta zada correlation hai
#or jitna zada dark color hai utna negative correlation hai
# Out:
# <AxesSubplot:>

# %%
#to this data in bar plot

# %%
df['quality'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#to check the distribution of any feature we use distplot

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
#or i can use histplot with kde = True

# %%
sns.histplot(df['volatile acidity'] , kde = True)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Count'>

# %%
#to chek the distribution of all features

# %%
for i in df:
    sns.histplot(df[i] , kde = True)

# %%
#we can also make categorical Plot

# %%
sns.catplot(x = 'quality' , y = 'alcohol' , data = df , kind = 'box')
#box -> to check the outliers

# %%
#to chcek the relationship between 2 features

# %%
sns.scatterplot(x = 'alcohol', y = 'pH' , hue = 'quality' , data = df )
#har ek category ke hissab se relationship pata chl jayega ph or alcohol ke beech me
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>
